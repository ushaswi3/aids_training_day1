# %%
import pandas as pd


df=pd.Series(['manager','junior developer','senior developer','junior developer','senior developer','manager','manager',
              'manager','senior developer','junior developer','manager','senior developer','junior manager','senior manager',
              'manager','manager','senior developer','manager','senior developer','manager','junior developer'])
df
# Out:
# 0              manager
# 1     junior developer
# 2     senior developer
# 3     junior developer
# 4     senior developer
# 5              manager
# 6              manager
# 7              manager
# 8     senior developer
# 9     junior developer
# 10             manager
# 11    senior developer
# 12      junior manager
# 13      senior manager
# 14             manager
# 15             manager
# 16    senior developer
# 17             manager
# 18    senior developer
# 19             manager
# 20    junior developer
# dtype: object

# %%
#performing level encoding
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder_emp = encoder.fit_transform(df)

print("Encoded Values:", encoder_emp)
print("Classes Mapping:", encoder.classes_)        # shows mapping order
print("Unique Encoded Labels:", pd.unique(encoder_emp))
# Out:
# Encoded Values: [2 0 3 0 3 2 2 2 3 0 2 3 1 4 2 2 3 2 3 2 0]
# Classes Mapping: ['junior developer' 'junior manager' 'manager' 'senior developer'
#  'senior manager']
# Unique Encoded Labels: [2 0 3 1 4]

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df = pd.Series([
    'manager','juniorDeveloper','juniorDeveloper','seniorDeveloper','manager',
    'seniorDeveloper','manager','seniorDeveloper','manager','juniorDeveloper',
    'juniorDeveloper','seniorDeveloper','manager','juniorDeveloper','juniorDeveloper',
    'seniorDeveloper','manager','juniorDeveloper','seniorDeveloper','seniorDeveloper',
    'manager'
])

encoder = LabelEncoder()
encoder_emp = encoder.fit_transform(df)

print("Encoded Values:", encoder_emp)
print("Classes Mapping:", encoder.classes_)        # shows mapping order
print("Unique Encoded Labels:", pd.unique(encoder_emp))
# Out:
# Encoded Values: [1 0 0 2 1 2 1 2 1 0 0 2 1 0 0 2 1 0 2 2 1]
# Classes Mapping: ['juniorDeveloper' 'manager' 'seniorDeveloper']
# Unique Encoded Labels: [1 0 2]

# %%
#label encoding
import pandas as pd

unique_cats = sorted(df.unique())
label_map = {cat: idx for idx, cat in enumerate(unique_cats)}

df_encoded = df.map(label_map)
print(df_encoded)
# Out:
# 0     1
# 1     0
# 2     0
# 3     2
# 4     1
# 5     2
# 6     1
# 7     2
# 8     1
# 9     0
# 10    0
# 11    2
# 12    1
# 13    0
# 14    0
# 15    2
# 16    1
# 17    0
# 18    2
# 19    2
# 20    1
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

data = ['Red', 'Green', 'Blue', 'Red']

le = LabelEncoder()
encoded_data = le.fit_transform(data)
print(f"Encoded Data: {encoded_data}")
# Out:
# Encoded Data: [2 1 0 2]

# %%
import pandas as pd

data = ['Red', 'Blue', 'Green', 'Red']

df = pd.DataFrame(data, columns=['Color'])
one_hot_encoded = pd.get_dummies(df['Color'])

print(one_hot_encoded)
# Out:
#     Blue  Green    Red
# 0  False  False   True
# 1   True  False  False
# 2  False   True  False
# 3  False  False   True

# %%
import pandas as pd

df = pd.Series([
    'manager','juniorDeveloper','juniorDeveloper','seniorDeveloper','manager',
    'seniorDeveloper','manager','seniorDeveloper','manager','juniorDeveloper',
    'juniorDeveloper','seniorDeveloper','manager','juniorDeveloper','juniorDeveloper',
    'seniorDeveloper','manager','juniorDeveloper','seniorDeveloper','seniorDeveloper',
    'manager'
])

# Level encoding
level_map = {'juniorDeveloper': 1, 'manager': 2, 'seniorDeveloper': 3}
df_level = df.map(level_map)
print(df_level.value_counts().sort_index())
# Output: 1    7, 3   14
# Out:
# 1    7
# 2    7
# 3    7
# Name: count, dtype: int64

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore',category=FutureWarning)

drive.mount('/content/drive')
path='/content/drive/MyDrive/Colab Notebooks/loan_approved.csv'
df=pd.read_csv(path)
# Out:
# Mounted at /content/drive

# %%
print("Shape:", df.shape)
print("\nData Types:")
print(df.dtypes)
ordinal = []
nominal = []
for col in df.columns:
    if df[col].dtype == 'object':
        nominal.append(col)
    elif df[col].dtype in ['int64', 'float64']:
        ordinal.append(col)
print("\nNominal Attributes:", nominal)
print("Ordinal / Numeric Attributes:", ordinal)
# Out:
# Shape: (614, 13)
#
# Data Types:
# Loan_ID                    object
# Gender                     object
# Married                    object
# Dependents                 object
# Education                  object
# Self_Employed              object
# ApplicantIncome             int64
# CoapplicantIncome         float64
# LoanAmount                float64
# Loan_Amount_Term          float64
# Credit_History            float64
# Property_Area              object
# Loan_Status (Approved)     object
# dtype: object
#
# Nominal Attributes: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status (Approved)']
# Ordinal / Numeric Attributes: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %%
df.head()
df.tail()
df.info()
df.shape
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  601 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              599 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           582 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              592 non-null    float64
#  9   Loan_Amount_Term        600 non-null    float64
#  10  Credit_History          564 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# ...

# %%
print(len(df['LoanAmount'].unique()))
print(len(df['Loan_Amount_Term'].unique()))
print(len(df['Credit_History'].unique()))
print(len(df['CoapplicantIncome'].unique()))
print(len(df['ApplicantIncome'].unique()))
# Out:
# 204
# 11
# 3
# 287
# 505

# %% [markdown]
# | Column            | Type        | Discrete/Continuous | Encoding Recommendation         |
# | ----------------- | ----------- | ------------------- | ------------------------------- |
# | Loan_ID           | Categorical | Discrete            | Drop (unique ID)                |
# | Gender            | Categorical | Discrete            | Label Encoding (binary)         |
# | Married           | Categorical | Discrete            | Label Encoding (binary)         |
# | Dependents        | Categorical | Discrete            | Label Encoding (ordinal-like)   |
# | Education         | Categorical | Discrete            | Label Encoding (binary)         |
# | Self_Employed     | Categorical | Discrete            | Label Encoding (binary)         |
# | ApplicantIncome   | Numerical   | Discrete            | None (integer counts)           |
# | CoapplicantIncome | Numerical   | Continuous          | None                            |
# | LoanAmount        | Numerical   | Continuous          | None                            |
# | Loan_Amount_Term  | Numerical   | Discrete            | None (term periods)             |
# | Credit_History    | Numerical   | Discrete            | None (binary 0/1)               |
# | Property_Area     | Categorical | Discrete            | One-Hot Encoding (3 categories) |
# | Loan_Status       | Categorical | Discrete            | Label Encoding (binary Y/N)     |

# %%
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])    #categorical,discrete-->mode,   continuous-->mean/median
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean()) # can use mean also cuz ther are no outliers which means the data is normally distributed so mean=median
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0]) # same
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0]) #
df.isnull().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status (Approved)    0
# dtype: int64

# %%
#gender label-encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender_encoded'] = le.fit_transform(df['Gender'])
print(f"Encoded Data: {df['Gender_encoded']}")
# Out:
# Encoded Data: 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Gender_encoded, Length: 614, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
encode_dep=LabelEncoder().fit_transform(df['Dependents'])
encode_gen=pd.get_dummies(df['Gender'],columns=['gender'],drop_first=True)
encode_edu=pd.get_dummies(df['Education'],columns=['edu'],drop_first=True)
df['dependents_count']=encode_dep
df['gender_male']=encode_gen
df['education_Not_Graduated']=encode_edu

df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)  Gender_encoded  \
# 0             1.0         Urban                      Y               1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
df['encode_dependents'] = LabelEncoder().fit_transform(df['Dependents'])
encode_gen = pd.get_dummies(df['Gender'], prefix='Gender', drop_first=True)
encode_edu = pd.get_dummies(df['Education'], prefix='Education', drop_first=True)
df = pd.concat([df, encode_gen, encode_edu], axis=1)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)  Gender_encoded  \
# 0             1.0         Urban                      Y               1
# ...

# %%
#z-score formula on ApplicantIncome  : (xi-mean)/sd
m=df['ApplicantIncome'].mean()
s=df['ApplicantIncome'].std()
df['zscore_applicant_income']=(df['ApplicantIncome']-m)/s
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['zscore_applicant_income'].max(),df['zscore_applicant_income'].min()
# Out:
# (12.374533479765521, -0.8599481824249576)

# %%
df['CoapplicantIncome'].kurtosis()
# Out:
# np.float64(84.95638421103374)

# %%
df['CoapplicantIncome'].skew()
# Out:
# np.float64(7.491531216657306)

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='yeo-johnson')
la_trans=trans.fit_transform(df[['CoapplicantIncome']])
la_trans.shape
print("skewness:",pd.Series(la_trans.reshape(614,)).skew())
print("Kurtosis:",pd.Series(la_trans.reshape(614,)).kurtosis)
sns.histplot(la_trans,kde=True)
# Out:
# skewness: -0.14564645710551902
# Kurtosis: <bound method Series.kurt of 0     -1.102837
# 1      0.750578
# 2     -1.102837
# 3      0.891686
# 4     -1.102837
#          ...
# 609   -1.102837
# 610   -1.102837
# 611    0.208603
# 612   -1.102837
# 613   -1.102837
# Length: 614, dtype: float64>
# <Axes: ylabel='Count'>

# %%
from sklearn.preprocessing import PowerTransformer
trans_app=PowerTransformer(method='yeo-johnson')
la_trans_app=trans_app.fit_transform(df[['ApplicantIncome']])
la_trans_app.shape
print("skewness:",pd.Series(la_trans_app.reshape(614,)).skew())
print("Kurtosis:",pd.Series(la_trans_app.reshape(614,)).kurtosis)
sns.histplot(la_trans_app,kde=True)
# Out:
# skewness: -0.09294567889276603
# Kurtosis: <bound method Series.kurt of 0      0.544331
# 1      0.170974
# 2     -0.499955
# 3     -0.743873
# 4      0.582817
#          ...
# 609   -0.554885
# 610   -0.000290
# 611    1.023487
# 612    0.931750
# 613    0.170974
# Length: 614, dtype: float64>
# <Axes: ylabel='Count'>

# %%
import seaborn as sns
import statsmodels.api as sm
sns.histplot(la_trans, kde=True)   # histogram + smooth normal curve
import numpy as np
la_log = np.log(la_trans + 1)  # add 1 to avoid log(0)
sns.histplot(la_log, kde=True)
sm.qqplot(la_log, line='45')
# Out:
# /tmp/ipython-input-3531498464.py:5: RuntimeWarning: invalid value encountered in log
#   la_log = np.log(la_trans + 1)  # add 1 to avoid log(0)
