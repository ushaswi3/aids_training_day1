# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
a_dict={'1st':1, '2nd':3, '3rd':5, '4th':7}
ser=pd.Series(a_dict)
ser
# Out:
# 1st    1
# 2nd    3
# 3rd    5
# 4th    7
# dtype: int64

# %% [markdown]
# ## 🎯 Your Task:
#
# Using **Pandas Series**, perform the following:
#
# ✅ Create a Series named `scores` using the dictionary `student_scores`.
#
# ✅ Print the marks scored by **"Charlie"** and **"Eva"**.
#
# ✅ Add **5 bonus marks** to all students and print the updated Series.
#
# ✅ Display only the students who scored **above 90** after the bonus.
#
# ✅ Calculate and print the **average marks** of the class (after the bonus).

# %%
import pandas as pd
import numpy as np
student_scores={'charlie':70, 'eva':75, 'alice':90, 'bob':72}
scores=pd.Series(student_scores)
print(scores['charlie'],scores['eva'])
scores=scores+5
print("Added 5 bonus marks to all students")
print("Updated scores:")
print(scores)
print("Students who scored above 90 after bonus:",scores[scores>90])
print("Average marks of students:",np.mean(scores))
# Out:
# 70 75
# Added 5 bonus marks to all students
# Updated scores:
# charlie    75
# eva        80
# alice      95
# bob        77
# dtype: int64
# Students who scored above 90 after bonus: alice    95
# dtype: int64
# Average marks of students: 81.75

# %%
import pandas as pd
import numpy as np
an_array=np.array([[25,85],[25,90],[26,70],[24,80]])
ser=pd.DataFrame(an_array,
                 index=['alice','bob','chirs','eva'],
                 columns=['age','marks'])
ser
print("values of the dataframe:",ser.values)
print("index of the dataframe:",ser.index)
print("columns of the dataframe:",ser.columns)
# Out:
# values of the dataframe: [[25 85]
#  [25 90]
#  [26 70]
#  [24 80]]
# index of the dataframe: Index(['alice', 'bob', 'chirs', 'eva'], dtype='object')
# columns of the dataframe: Index(['age', 'marks'], dtype='object')

# %%
 import pandas as pd
 a_dict={'name':{'ru':'rukshan','pr':'prasad','gi':'giya','ha':'hasini'},
         'age':{'ru':25,'pr':25,'gi':26,'ha':22},
         'marks':{'ru':85,'pr':90,'gi':96,'ha':82}}
df=pd.DataFrame(a_dict)
df
# Out:
#        name  age  marks
# ru  rukshan   25     85
# pr   prasad   25     90
# gi     giya   26     96
# ha   hasini   22     82

# %%
 import pandas as pd
 print("DataFrame creation: Using Dictionaries and lists")
 a_dict={'name':['rukshan','prasad','giya','hasini'],
         'age':[25,25,26,22],
         'marks':[85,90,96,82]}
df=pd.DataFrame(a_dict)
print(df)
print(df.index)
print(df.values)
print(df.columns)
print(df.shape)
print(df.size)
print(df.dtypes)
print(df.values.ndim)
print(df.values.shape)
# Out:
# DataFrame creation: Using Dictionaries and lists
#       name  age  marks
# 0  rukshan   25     85
# 1   prasad   25     90
# 2     giya   26     96
# 3   hasini   22     82
# RangeIndex(start=0, stop=4, step=1)
# [['rukshan' 25 85]
#  ['prasad' 25 90]
#  ['giya' 26 96]
#  ['hasini' 22 82]]
# Index(['name', 'age', 'marks'], dtype='object')
# (4, 3)
# 12
# name     object
# age       int64
# marks     int64
# dtype: object
# 2
# (4, 3)

# %%
import pandas as pd
print("DataFrame creation: Using Dictionaries of series")
ser1=pd.Series(['rukshan','prasad','giya','hasini'],index=['ru','pr','gi','hs'])
ser2=pd.Series([25,25,26,22],index=['ru','pr','gi','hs'])
ser3=pd.Series([85,90,96,82],index=['ru','pr','gi','hs'])
a_dict={'name':ser1,
        'age':ser2,
        'marks':ser3}

df=pd.DataFrame(a_dict)
df
# Out:
# DataFrame creation: Using Dictionaries of series
#        name  age  marks
# ru  rukshan   25     85
# pr   prasad   25     90
# gi     giya   26     96
# hs   hasini   22     82

# %% [markdown]
# You are given three Series representing student data:
#
# Names of students
#
# Their ages
#
# Their marks
#
# These series are combined into a DataFrame as shown earlier.
#
# ### 🎯 Your Task:
# Using the existing DataFrame, perform the following operations:
#
# ✅ Print the details (name, age, marks) of the student who scored the highest marks.
#
# ✅ Add a new student "Tharushi" with age 23 and marks 88 using the index "Th".
#
# ✅ Display the details of students who are 25 years old or older.
#
# ✅ Increase the marks of students below 80 by 10 bonus points.
#
# ✅ Calculate and print the average marks of all students after the bonus.

# %%
import pandas as pd
ser1=pd.Series(['rukshan','prasad','giya','hasini'],index=['ru','pr','gi','hs'])
ser2=pd.Series([25,25,26,22],index=['ru','pr','gi','hs'])
ser3=pd.Series([85,90,96,82],index=['ru','pr','gi','hs'])
a_dict={'name':ser1,
        'age':ser2,
        'marks':ser3}

df=pd.DataFrame(a_dict)
df
highest = df[df['marks'] == df['marks'].max()]
print("Student with the highest marks:\n", highest)
print("\n")
df.loc['Th'] = ['Tharushi', 23, 88]
print("After adding Tharushi:\n", df)
print("\n")
older_students = df[df['age'] >= 25]
print("Students aged 25 or older:\n", older_students)
print("\n")
df.loc[df['marks'] < 80, 'marks'] += 10
print("After giving 10 bonus marks to students below 80:\n", df)
print("\n")
average_marks = df['marks'].mean()
print(f"Average marks after adding bonus: {average_marks:.2f}")
# Out:
# Student with the highest marks:
#      name  age  marks
# gi  giya   26     96
#
#
# After adding Tharushi:
#          name  age  marks
# ru   rukshan   25     85
# pr    prasad   25     90
# gi      giya   26     96
# hs    hasini   22     82
# Th  Tharushi   23     88
#
#
# Students aged 25 or older:
#         name  age  marks
# ru  rukshan   25     85
# pr   prasad   25     90
# gi     giya   26     96
#
#
# After giving 10 bonus marks to students below 80:
#          name  age  marks
# ru   rukshan   25     85
# pr    prasad   25     90
# gi      giya   26     96
# hs    hasini   22     82
# Th  Tharushi   23     88
#
#
# Average marks after adding bonus: 88.20

# %%
from google.colab import drive
import pandas as pd

#Mount your Drive
drive.mount('/content/drive')

#once mounted,navigate to the folder
#example path(adjust bsed on your structure)
path='/content/drive/My Drive/Colab Notebooks/data.csv'

df=pd.read_csv(path)
print(df.head())
# Out:
# Mounted at /content/drive
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0

# %%
print(df.info())
print(df.isnull())
print(df.isnull().sum())

#to drop the na values
new_df=df.dropna()
print(new_df.to_string())

#to fill the na values
df.fillna(130,inplace=True)
print(df)

#na with median
x=df["Calories"].median()
df.fillna({"Calories":x},inplace=True)
print("\n")
print(df)

#na with mode
x=df["Calories"].mode()
df.fillna({"Calories":x},inplace=True)
print("\n")
print(df)

#na with mean
x=df["Calories"].mean()
df.fillna({"Calories":x},inplace=True)
print("\n")
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      32 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB
# None
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# ...

# %%
from google.colab import drive
import pandas as pd

#Mount your Drive
drive.mount('/content/drive')

#once mounted,navigate to the folder
#example path(adjust bsed on your structure)
path='/content/drive/My Drive/Colab Notebooks/data.csv'

df=pd.read_csv(path)

print(df.info())
print(df.isnull())
print(df.isnull().sum())

#to fill the na values
#df.fillna(130,inplace=True)
#print(df)

#na with median
#x=df["Calories"].median()
#df.fillna({"Calories":x},inplace=True)
#print("\n")
#print(df)

#na with mode
#x=df["Calories"].mode()
#df.fillna({"Calories":x},inplace=True)
#print("\n")
#print(df)

#na with mean
x=df["Calories"].mean()
df.fillna({"Calories":x},inplace=True)
print("\n")
print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB
# None
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# ...

# %%
from google.colab import drive
import pandas as pd

#once mounted,navigate to the folder
#example path(adjust bsed on your structure)
path='/content/drive/My Drive/Colab Notebooks/data.csv'

df=pd.read_csv(path)


df['Date']=pd.to_datetime(df['Date'],format='mixed')
print(df.to_string())
df.dropna(subset=['Date'],inplace=True)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.loc[7,'Duration']=45
print(df.to_string())

for x in df.index:
  if df.loc[x,"Duration"]>120:
    df.drop(x,inplace=True)

print(df.duplicated())
df.drop_duplicates(inplace=True)

#Filtering
#filter:rows where pulse>110
high_pulse=df[df['Pulse']>110]
print(high_pulse)

#sorting
#sort by calories descending
sorted_df=df.sort_values(by='Calories',
                         ascending=False)
print(sorted_df)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %%
# Create another DataFrame with Date and Trainer name
trainer_df = pd.DataFrame({
    'Date': ['2020/12/01', '2020/12/02', '2020/12/03'],
    'Trainer': ['Alex', 'Jordan', 'Taylor']
})

# Convert 'Date' column in trainer_df to datetime format
trainer_df['Date'] = pd.to_datetime(trainer_df['Date'])

# Now merge
merged_df = pd.merge(df, trainer_df, on='Date', how='left')

print(merged_df)

## Group by Duration and Calculate Average Calories
### Groups the dataset by the Duration column (i.e., how long each activity lasted).
### For each unique Duration, it computes the average Calories burned.
### Returns a Series with Duration as the index and average Calories as values.


# Group by Duration and get average Calories
avg_calories_by_duration = df.groupby('Duration')['Calories'].mean()

# Group by Pulse range (bucketed)
df['PulseRange'] = pd.cut(df['Pulse'], bins=[100, 110, 120, 130, 140, 150, 180])
grouped_stats = df.groupby('PulseRange', observed=False).agg({
    'Calories': 'mean',
    'Maxpulse': 'max'
})

print(grouped_stats)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories Trainer
# 0         60 2020-12-01    110       130     409.1    Alex
# 1         60 2020-12-02    117       145     479.0  Jordan
# 2         60 2020-12-03    103       135     340.0  Taylor
# 3         45 2020-12-04    109       175     282.4     NaN
# 4         45 2020-12-05    117       148     406.0     NaN
# 5         60 2020-12-06    102       127     300.0     NaN
# 6         60 2020-12-07    110       136     374.0     NaN
# 7         45 2020-12-08    104       134     253.3     NaN
# 8         30 2020-12-09    109       133     195.1     NaN
# 9         60 2020-12-10     98       124     269.0     NaN
# 10        60 2020-12-11    103       147     329.3     NaN
# 11        60 2020-12-12    100       120     250.7     NaN
# 12        60 2020-12-13    106       128     345.3     NaN
# 13        60 2020-12-14    104       132     379.3     NaN
# 14        60 2020-12-15     98       123     275.0     NaN
# ...

# %% [markdown]
# Data Correlations- Finding Relationships
#
# A great aspect of the Pandas module is the corr() method.
# The corr() method calculates the relationship between each column in your data set.
#
# df.corr()
#
# Note: The corr() method ignores "not numeric" columns.
#
#                       Duration     Pulse         Maxpulse    Calories
#   Duration  1.000000    -0.155408  0.009403      0.922721
#   Pulse        -0.155408    1.000000   0.786535      0.025120
#   Maxpulse  0.009403    0.786535   1.000000      0.203814
#   Calories  0.922721    0.025120   0.203814      1.000000
#
# The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
#
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# What is a good correlation? It depends on the use, but I think it is safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.
#
# Perfect Correlation:
# We can see that "Duration" and "Duration" got the number 1.000000, which makes sense, each column always has a perfect relationship with itself.
#
# Good Correlation:
# "Duration" and "Calories" got a 0.922721 correlation, which is a very good correlation, and we can predict that the longer you work out, the more calories you burn, and the other way around: if you burned a lot of calories, you probably had a long work out.
#
# Bad Correlation:
# "Duration" and "Maxpulse" got a 0.009403 correlation, which is a very bad correlation, meaning that we can not predict the max pulse by just looking at the duration of the work out, and vice versa.

# %%
# Create the Trainer DataFrame
trainer_df = pd.DataFrame({
    'Date': ['2020/12/01', '2020/12/02', '2020/12/03'],
    'Trainer': ['Alex', 'Jordan', 'Taylor']
})

# Convert date to datetime
trainer_df['Date'] = pd.to_datetime(trainer_df['Date'])

# Merge with main df
df = pd.merge(df, trainer_df, on='Date', how='left')

# Fill missing trainers if needed
df['Trainer'].fillna('Unknown', inplace=True)

# Now this will work
#df.value_counts() for frequency distribution
print(df['Trainer'].value_counts())

#Renaming columns(rename()):
df.rename(columns={'Maxpulse':'Max_Pulse'},inplace=True)
df

#df.describe() for summary stats
print(df.describe())
# Out:
# Trainer
# Unknown    27
# Alex        1
# Jordan      1
# Taylor      1
# Name: count, dtype: int64
#         Duration                 Date       Pulse   Max_Pulse    Calories
# count  30.000000                   30   30.000000   30.000000   28.000000
# mean   56.000000  2020-12-15 19:12:00  103.733333  129.100000  307.417857
# min    30.000000  2020-12-01 00:00:00   90.000000  101.000000  195.100000
# 25%    60.000000  2020-12-08 06:00:00  100.000000  120.750000  250.525000
# 50%    60.000000  2020-12-15 12:00:00  103.000000  128.500000  300.000000
# 75%    60.000000  2020-12-23 18:00:00  107.500000  132.750000  350.025000
# max    60.000000  2020-12-31 00:00:00  130.000000  175.000000  479.000000
# std     7.812457                  NaN    8.042702   13.215325   67.412594
# /tmp/ipython-input-1884162814.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Convert Trainer names to Title Case
df['Trainer'] = df['Trainer'].str.title()

# Filter trainers containing 'Alex'
print("Trainers containing 'Alex':")
print(df[df['Trainer'].str.contains('Alex', case=False, na=False)], "\n")

# Convert to lowercase
df['Trainer'] = df['Trainer'].str.lower()
print("Lowercase Trainer names:")
print(df.head(), "\n")

# Convert to uppercase
df['Trainer'] = df['Trainer'].str.upper()
print("Uppercase Trainer names:")
print(df.head(), "\n")

# Filter trainers starting with 'A'
print("Trainers starting with A:")
print(df[df['Trainer'].str.startswith('A', na=False)], "\n")

# Get length of each Trainer name (number of characters)
df['Trainer_Length'] = df['Trainer'].str.len()
print("Trainer name lengths:")
print(df[['Trainer', 'Trainer_Length']])
# Out:
# Trainers containing 'Alex':
#    Duration       Date  Pulse  Max_Pulse  Calories  PulseRange Trainer_x  \
# 0        60 2020-12-01    110        130     409.1  (100, 110]      Alex
#
#   Trainer_y Trainer
# 0      Alex    Alex
#
# Lowercase Trainer names:
#    Duration       Date  Pulse  Max_Pulse  Calories  PulseRange Trainer_x  \
# 0        60 2020-12-01    110        130     409.1  (100, 110]      Alex
# 1        60 2020-12-02    117        145     479.0  (110, 120]    Jordan
# 2        60 2020-12-03    103        135     340.0  (100, 110]    Taylor
# 3        45 2020-12-04    109        175     282.4  (100, 110]   Unknown
# 4        45 2020-12-05    117        148     406.0  (110, 120]   Unknown
#
#   Trainer_y  Trainer
# 0      Alex     alex
# 1    Jordan   jordan
# 2    Taylor   taylor
# 3       NaN  unknown
# 4       NaN  unknown
#
# Uppercase Trainer names:
#    Duration       Date  Pulse  Max_Pulse  Calories  PulseRange Trainer_x  \
# ...

# %% [markdown]
# import kagglehub
#
# # Download latest version
# path = kagglehub.dataset_download("vijayuv/onlineretail")
#
# print("Path to dataset files:", path)
